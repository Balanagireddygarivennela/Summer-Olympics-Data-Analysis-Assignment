# %% [markdown]
# 1. In how many Cities Summer Olympics is held so far

# %%
import pandas as pd

# %%
df= pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# 31164  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
#
# ...

# %%
df['City'].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
len(df['City'].unique())
# Out:
# 22

# %% [markdown]
# 2. Which sport is having more number of GoldMedals

# %%
Gold_Medals = df[df['Medal']=='Gold']

# %%
Gold_Medals.groupby('Sport').Medal.count().sort_values(ascending = False).head()
# Out:
# Sport
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Medal, dtype: int64

# %%
Gold_Medals.groupby('Sport').Medal.count().sort_values(ascending = False).head().plot.bar(figsize=(6,5))

# %%
Gold_Medals.Sport.value_counts().sort_values(ascending = False).head().plot.bar(figsize=(6,5))

# %% [markdown]
# 3.Which Sport is having most number of medals so far?(Top 5)

# %%
Sports = df.groupby('Sport').Medal.count().sort_values(ascending = False).head()
Sports
# Out:
# Sport
# Aquatics      4170
# Athletics     3638
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Medal, dtype: int64

# %%
df.groupby('Sport').Medal.count().sort_values(ascending = False).head().plot.bar(figsize = (6,5))

# %% [markdown]
# 4. Which player has won most number of medals?(Top 5)

# %%
Best_Player = df.groupby('Athlete').Medal.count().sort_values(ascending = False).head()
Best_Player
# Out:
# Athlete
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# SHAKHLIN, Boris         13
# Name: Medal, dtype: int64

# %%
Best_Player.plot.bar(figsize = (6,5))

# %% [markdown]
# 5. Which player has won most number Gold medals of medals(Top 5)

# %%
GoldPlayer = Gold_Medals.Athlete.value_counts().sort_values(ascending = False).head()
GoldPlayer
# Out:
# PHELPS, Michael     18
# NURMI, Paavo         9
# SPITZ, Mark          9
# LATYNINA, Larisa     9
# LEWIS, Carl          9
# Name: Athlete, dtype: int64

# %%
Gold_Medals.groupby('Athlete').Medal.count().sort_values(ascending = False).head()
# Out:
# Athlete
# PHELPS, Michael     18
# NURMI, Paavo         9
# SPITZ, Mark          9
# LEWIS, Carl          9
# LATYNINA, Larisa     9
# Name: Medal, dtype: int64

# %%
GoldPlayer.plot.bar(figsize = (6,5))

# %% [markdown]
# 6 . In which year India won first Gold Medal in Summer Olympics?

# %%
Gold_Medals
# Out:
#        Year    City      Sport  ... Gender                       Event Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle  Gold
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Gold
# 6      1896  Athens   Aquatics  ...    Men             1200M Freestyle  Gold
# 9      1896  Athens   Aquatics  ...    Men              400M Freestyle  Gold
# 13     1896  Athens  Athletics  ...    Men                        100M  Gold
# ...     ...     ...        ...  ...    ...                         ...   ...
# 31145  2012  London  Wrestling  ...    Men                    Wg 60 KG  Gold
# 31149  2012  London  Wrestling  ...    Men                    Wg 66 KG  Gold
# 31153  2012  London  Wrestling  ...    Men                    Wg 74 KG  Gold
# 31157  2012  London  Wrestling  ...    Men                    Wg 84 KG  Gold
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG  Gold
#
# [10486 rows x 9 columns]

# %%
India_g1 = Gold_Medals[Gold_Medals['Country']=='IND']
India_g1
# Out:
#        Year       City     Sport  ... Gender                     Event Medal
# 5512   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5513   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5514   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5515   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5516   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# ...     ...        ...       ...  ...    ...                       ...   ...
# 16099  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16100  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16101  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16102  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 28856  2008    Beijing  Shooting  ...    Men  10M Air Rifle (60 Shots)  Gold
#
# [128 rows x 9 columns]

# %%
India_g1.sort_values(by = 'Year' ,ascending = True).head(1)
# Out:
#       Year       City   Sport Discipline  ... Country Gender   Event Medal
# 5512  1928  Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
#
# [1 rows x 9 columns]

# %% [markdown]
# 7. Which event is most popular in terms of number of players(Top 5)?

# %%
Popular = df.groupby('Event').Athlete.count().sort_values(ascending = False).head()
Popular
# Out:
# Event
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Athlete, dtype: int64

# %%
Popular.plot.bar(figsize = (6,5))

# %% [markdown]
# 8 . Which sport is having most female Gold medalists(Top 5)?

# %%
Female_Players = df[df['Gender']=='Women']
Female_Players
# Out:
#        Year    City      Sport  ... Gender          Event   Medal
# 416    1900   Paris       Golf  ...  Women     Individual  Bronze
# 417    1900   Paris       Golf  ...  Women     Individual    Gold
# 418    1900   Paris       Golf  ...  Women     Individual  Silver
# 639    1900   Paris     Tennis  ...  Women  Mixed Doubles  Bronze
# 640    1900   Paris     Tennis  ...  Women  Mixed Doubles  Bronze
# ...     ...     ...        ...  ...    ...            ...     ...
# 31116  2012  London  Wrestling  ...  Women       Wf 63 KG  Bronze
# 31121  2012  London  Wrestling  ...  Women       Wf 72 KG    Gold
# 31122  2012  London  Wrestling  ...  Women       Wf 72 KG  Silver
# 31123  2012  London  Wrestling  ...  Women       Wf 72 KG  Bronze
# 31124  2012  London  Wrestling  ...  Women       Wf 72 KG  Bronze
#
# [8419 rows x 9 columns]

# %%
Female_goldmedalists =Female_Players[Female_Players['Medal']=='Gold']
Female_goldmedalists
# Out:
#        Year      City  ...                                    Event Medal
# 417    1900     Paris  ...                               Individual  Gold
# 641    1900     Paris  ...                            Mixed Doubles  Gold
# 649    1900     Paris  ...                                  Singles  Gold
# 710    1904  St Louis  ...  Double Columbia Round (50Y - 40Y - 30Y)  Gold
# 713    1904  St Louis  ...        Double National Round (60Y - 50Y)  Gold
# ...     ...       ...  ...                                      ...   ...
# 31081  2012    London  ...                                     75KG  Gold
# 31097  2012    London  ...                                 Wf 48 KG  Gold
# 31105  2012    London  ...                                 Wf 55 KG  Gold
# 31113  2012    London  ...                                 Wf 63 KG  Gold
# 31121  2012    London  ...                                 Wf 72 KG  Gold
#
# [2788 rows x 9 columns]

# %%
Female_gold_sports=Female_goldmedalists.groupby('Sport').Medal.count().sort_values(ascending = False).head()
Female_gold_sports
# Out:
# Sport
# Aquatics      589
# Athletics     389
# Gymnastics    268
# Rowing        217
# Volleyball    166
# Name: Medal, dtype: int64

# %%
Female_gold_sports.plot.bar(figsize = (6,5))
